# %% [markdown]
# # The Battle of the Neighborhoods

# %% [markdown]
# ## Introduction

# %% [markdown]
# Tourism is a global industry and has been around for a long period of time. Tourism bolsters the economy and can do great things for the community where tourism takes place. Tourism creates demand,bolsters other aspects of the economy and other sectors across the world and it induces more consumption.

# %% [markdown]
# <h3>Buisness Objective</h3>

# %% [markdown]
# The benefits of tourism can be seen very clearly in the city of London,a city which I myself have visited as a tourist.London is tourist hot spot and millions of people flock to this city to enjoy the wonderful sites.  This project looks to see where a new resteraunt owner would want to open in  the city.
#
# The target audience of this report is anyone in the tourism city in London or in big cities around the world. They can take the insight from this report and apply it to other cities.

# %% [markdown]
# <h4>Data Used</h4>

# %% [markdown]
# To complete the task above we will need to create a dataframe of all of the districs the city as well as the geographical coordiantes of the city.
#
# The source code will come from https://en.wikipedia.org/wiki/Community_areas_in_Chicago.  This page gives us a list of all the neighborhoods in Chicago. We will us beautifulsoup4 package to extract the data and then use geophy to find the coordinates.

# %% [markdown]
# <h4>Data Description</h4>

# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# %%
url = "https://en.wikipedia.org/wiki/Community_areas_in_Chicago"
wiki_chicago_url = requests.get(url)
wiki_chicago_url
# Out:
# <Response [200]>

# %%
wiki_chicago_data = pd.read_html(wiki_chicago_url.text)
wiki_chicago_data
# Out:
# [   Number[8]          Name[8]  2017[9] Area (sq mi.)[10]  Area (km2)  \
#  0         01      Rogers Park    55062              1.84        4.77
#  1         02       West Ridge    76215              3.53        9.14
#  2         03           Uptown    57973              2.32        6.01
#  3         04   Lincoln Square    41715              2.56        6.63
#  4         05     North Center    35789              2.05        5.31
#  ..       ...              ...      ...               ...         ...
#  73        74  Mount Greenwood    19277              2.71        7.02
#  74        75      Morgan Park    22394              3.30        8.55
#  75        76           O'Hare    12377             13.34       34.55
#  76        77        Edgewater    55965              1.74        4.51
#  77     Total          Chicago  2722586        227.34[12]      588.81
#
#      2017density (/sq mi.)  2017density (/km2)
#  0                29925.00            11554.11
# ...

# %%
wiki_chicago_data = wiki_chicago_data[1]
wiki_chicago_data
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteCommunity areas in Chicago  \
# ...
